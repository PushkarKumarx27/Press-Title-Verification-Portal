# %%
import pandas as pd

# %%
df1 = pd.read_excel('TestExcel(1).xlsx')
df2 = pd.read_excel('TestExcel(2).xlsx')
df3 = pd.read_excel('TestExcel(3).xlsx')
df4 = pd.read_excel('TestExcel(4).xlsx')
df5 = pd.read_excel('TestExcel.xlsx')

# %%
df_comb = pd.concat([df1, df2, df3, df4, df5])

df_comb.to_csv("Dataset.csv")

# %%
df  = pd.read_csv('Dataset.csv')
df.head()
# Out:
#    Unnamed: 0   Title-Code                 Title Name  Hindi Title  \
# 0           0     NOF00025                ANUJA TIMES          NaN
# 1           1     NOF00028  NEEL GAGAN SAMACHAR TIMES          NaN
# 2           2  NOFHIN00548    AAP SUB KA SAHARA TIMES          NaN
# 3           3  NOFHIN00556           JAN JAGRAN TIMES          NaN
# 4           4  ANDENG00151                TODAY TIMES  टुडे टाइम्स
#
#    Register Serial No           Regn No.     Owner Name State  \
# 0             48613.0           48613/ 0            NOF   NaN
# 1             58610.0          58610/ 94      NOT GIVEN   NaN
# 2             55677.0          55677/ 92      NOT GIVEN   NaN
# 3             62359.0          62359/ 94      NOT GIVEN   NaN
# 4            125860.0  ANDENG/2013/53305  PRADEEP KUMAR   AND
#
#   Publication City/District Periodity
# 0                       NaN       NaN
# 1                       NaN         A
# 2                       NaN         W
# ...

# %%
df.shape
# Out:
# (14166, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14166 entries, 0 to 14165
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 14166 non-null  int64
#  1   Title-Code                 14166 non-null  object
#  2   Title Name                 14166 non-null  object
#  3   Hindi Title                5195 non-null   object
#  4   Register Serial No         13288 non-null  float64
#  5   Regn No.                   13537 non-null  object
#  6   Owner Name                 14155 non-null  object
#  7   State                      14160 non-null  object
#  8   Publication City/District  14152 non-null  object
#  9   Periodity                  14165 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Unnamed: 0                      0
# Title-Code                      0
# Title Name                      0
# Hindi Title                  8971
# Register Serial No            878
# Regn No.                      629
# Owner Name                     11
# State                           6
# Publication City/District      14
# Periodity                       1
# dtype: int64

# %%
df['Title Name'].duplicated().sum()
# Out:
# 2634

# %%
new_df = df.drop_duplicates(subset='Title Name')

# %%
new_df['Title Name'].duplicated().sum()
# Out:
# 0

# %%
new_df.shape
# Out:
# (11532, 10)

# %%
new_df.to_csv("New_Dataset.csv")
